# %%
import os

from IPython.core import payload
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}","Content-Type": "application/json"}

payload = {
    "model":"gpt-5-nano",
    "messages":[
    {"role":"user","content":"tell me a fun fact"}
]
}

payload

# %% [markdown]
# ## Calling Open AI using Cloud

# %%
response = requests.post(
    "https://api.openai.com/v1/chat/completions",
    headers=headers,
    json=payload
)

response.json()

# %%
response.json()["choices"][0]["message"]["content"]

# %% [markdown]
# ## The Other way of doing IT

# %%
# Create OpenAI client

from openai import OpenAI
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content

# %% [markdown]
# ## And Ollama also gives an OpenAI compatible endpoint
#
# ...and it's on your local machine!
#
# If "Ollama is not running" then please open a terminal and run `ollama serve`

# %%
requests.get("http://localhost:11434").content

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# Get a fun fact

response = ollama.chat.completions.create(model="phi3", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'Fun Fact: The shortest war in history was declared on April 25, 1864, during the New Zealand Wars. Lasting only from May 1 to October 10 of that same year and involving just 37 people - two soldiers each at opposite ends of a trench rowed along with some "artillery", it\'s recorded as having occurred between British-backed Maori forces on one end, with the other side consisting mainly Te Roroa warriors. Despite its brevity in duration and participation, this miniature conflict noneththeless led to discussions about greater freedom of self-governance for New Zealand’s indigenous peoples - a sentiment that has echoed through much progress ongoing today!'
